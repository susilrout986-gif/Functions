# %%
1)
An interpreted language is executed line by line by an interpreter at runtime.
A compiled language is translated into machine code before it is executed
2)
Exception handling in Python is a mechanism that allows your program to detect and respond to errors gracefully instead of crashing. It lets you handle unexpected situations—like missing files, invalid input, or division by zero—without stopping the entire program.
3)To ensure that certain code always executes, no matter what happens in the try/catch.
4)In Python, logging refers to the built-in mechanism for recording events that happen while your program runs. It’s extremely useful for debugging, monitoring, auditing, or tracking the flow and state of  application—especially when it grows large or runs in production.
5)In Python, __del__ is a destructor method—it is called when an object is about to be destroyed
6)
In Python, import and from ... import ... both bring external modules or objects into your code, but they work differently and affect namespace, readability, and memory usage in different ways.
import Loads the entire module.
from..import..Imports specific functions, classes, or variables from a module into your current namespace.

7)
a.Catch multiple exceptions in one except block
b.Use multiple except blocks
c.Use a base class for exception hierarchy
d.Handle multiple exceptions using Exception
8)
In Python, the with statement is used when working with files to ensure proper setup and automatic cleanup, even if errors occur.
9)a.Multithreading Uses multiple threads within the same process.All threads share the same memory space
  b.Uses multiple processes, each with its own memory space.Processes do not share memory unless explicitly configured.
10)Using logging in a program provides a structured, reliable, and scalable way to understand what your software is doing at runtime.
11)Memory management in Python refers to how Python allocates, uses, and frees memory while program runs. Python handles most memory operations automatically, which makes it easier for developers—but understanding how it works helps to write faster and more memory-efficient code.
12)In Python, exception handling is done using the try–except mechanism.
a.Identify the risky code
b.Catch the exception
c.Handle the error
13)
a.Performance: Speed & Efficiency
b.Python’s Garbage Collection Has Limits
c.Working With Large Data
d.Stability & Avoiding Crashes
14)In Python, try and except are the core components of exception handling, which allows program to run smoothly even when unexpected errors occur.
15)Python uses automatic memory management, combining reference counting and a cyclic garbage collector to reclaim memory that is no longer needed. Here’s a clear breakdown of how it works:
a.Reference Counting 
b.Cyclic Garbage Collector
c.Finalizers and Weak Reference
16)In exception handling, the else block is used to define code that should run only if no exception occurs in the try block.
17)In Python, logging levels are used to indicate the severity or importance of a log message. The built-in logging module defines several standard logging levels, each associated with a numeric value
18)
When we call os.fork(), the OS creates a new process with a separate memory space, but initially, it is an almost exact copy of the parent. The return value distinguishes parent from child.
multiprocessing is a high-level, cross-platform module in Python that abstracts process creation and provides tools for parallel computing.
19)
Closing a file in Python is important for several key reasons, mainly related to resource management, data integrity, and program stability.
20)
file.read() Reads the entire contents of a file (or a specified number of bytes) at once.
file.readLine() Reads one line at a time from the file.
21)
The logging module in Python is used to track events that happen when software runs. It provides a flexible framework for emitting log messages from Python programs. These messages can help developers and system administrators debug code, monitor applications, or record runtime events without using print statements.
22)
The os module in Python is a standard library module that provides a way to interact with the operating system. In the context of file handling, it’s primarily used for tasks that involve the filesystem rather than reading or writing file content . Essentially, os lets you manage files and directories programmatically.
23)
a.Python uses automatic memory management via reference counting and garbage collection (GC).
b.Memory Leaks
c.Large Object and Data Structure Management
d.Managing Memory in Multithreading and Multiprocessing
24)In Python, we can raise an exception manually using the raise statement. This is useful when we want to signal that an error condition has occurred
25)Using multithreading in applications is important because it allows programs to perform multiple tasks concurrently, which can lead to significant improvements in performance, responsiveness, and resource utilization

Practical Questions:
1)In Python, you can open a file for writing using the built-in open() function with mode "w" (write). Once the file is open, you can write a string to it using the write() method. Example:

with open("example.txt", "w") as file:
    # Write a string to the file
    file.write("Hello, world!\n")
2)file_name = 'example.txt'

with open(file_name, 'r') as file:
    # Read and print each line
    for line in file:
        print(line, end='') 
3)When trying to open a file for reading, if the file does not exist, attempting to open it directly will raise an error.To handle this gracefully,  can use exception handling to catch the error and respond appropriately.
filename = "example.txt"

try:
    with open(filename, "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
4)input_file = 'input.txt'
output_file = 'output.txt'

try:
        with open(input_file, 'r') as infile:
        content = infile.read()      
    with open(output_file, 'w') as outfile:
        outfile.write(content)  
5)n Python, you can catch and handle a division by zero error using a try-except block. The error raised for division by zero is called ZeroDivisionError. Here's a clear example:

try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
# Out:
# Hello World

# %%
# Out:
#   Cell In[5], line 5
#     print(num+ ":is Prime Number")
#     ^
# IndentationError: unexpected indent
